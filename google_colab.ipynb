# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
credited_card_df = pd.read_csv('/content/creditcard.csv', on_bad_lines='skip', low_memory=False)

credited_card_df.head()
# Out:
#    Time        V1                   V2        V3        V4        V5  \
# 0     0 -1.359807  -0.0727811733098497  2.536347  1.378155 -0.338321
# 1     0  1.191857     0.26615071205963  0.166480  0.448154  0.060018
# 2     1 -1.358354    -1.34016307473609  1.773209  0.379780 -0.503198
# 3     1 -0.966272   -0.185226008082898  1.792993 -0.863291 -0.010309
# 4     2 -1.158233    0.877736754848451  1.548718  0.403034 -0.407193
#
#          V6        V7        V8        V9  ...       V21       V22       V23  \
# 0  0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474
# 1 -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288
# 2  1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412
# 3  1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321
# 4  0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
credited_card_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45635 entries, 0 to 45634
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    45635 non-null  int64
#  1   V1      45635 non-null  float64
#  2   V2      45635 non-null  object
#  3   V3      45635 non-null  float64
#  4   V4      45635 non-null  float64
#  5   V5      45635 non-null  float64
#  6   V6      45634 non-null  float64
#  7   V7      45633 non-null  float64
#  8   V8      45633 non-null  float64
#  9   V9      45633 non-null  float64
#  10  V10     45633 non-null  object
#  11  V11     45633 non-null  float64
#  12  V12     45633 non-null  float64
#  13  V13     45633 non-null  float64
#  14  V14     45633 non-null  float64
#  15  V15     45633 non-null  float64
#  16  V16     45631 non-null  float64
#  17  V17     45631 non-null  float64
#  18  V18     45630 non-null  float64
#  19  V19     45629 non-null  float64
# ...

# %%
credited_card_df.shape
# Out:
# (45635, 31)

# %%
credited_card_df['Class'].value_counts()
# Out:
# Class
# 0.0    45480
# 1.0      145
# Name: count, dtype: int64

# %%
credited_card_df.describe()
# Out:
#                Time            V1            V3            V4            V5  \
# count  45635.000000  45635.000000  45635.000000  45635.000000  45635.000000
# mean   30713.848647     -0.263621      0.689066      0.196027     -0.252874
# std    15423.934564      1.896061      1.523670      1.401311      1.409143
# min        0.000000    -56.407510    -32.965346     -5.172595    -32.092129
# 25%    19891.000000     -1.005397      0.219062     -0.701606     -0.865003
# 50%    38645.000000     -0.280423      0.794289      0.204070     -0.280710
# 75%    43496.000000      1.154245      1.430418      1.069589      0.286184
# max    48871.000000      1.960497      4.101716     16.715537     34.801666
#
#                  V6            V7            V8            V9           V11  \
# count  45634.000000  45633.000000  45633.000000  45633.000000  45633.000000
# mean       0.101293     -0.125635      0.055670      0.148939      0.377626
# ...

# %%
legit = credited_card_df[credited_card_df.Class==0]
fraud = credited_card_df[credited_card_df['Class']==1]

# %%
fraud.shape
# Out:
# (145, 31)

# %%
legit.shape
# Out:
# (45480, 31)

# %%
legit_sample = legit.sample(n=145)
credited_card_df = pd.concat([legit_sample,fraud],axis=0)

# %%
credited_card_df['Class'].value_counts()
# Out:
# Class
# 0.0    145
# 1.0    145
# Name: count, dtype: int64

# %%
print(credited_card_df.dtypes)
# Out:
# Time        int64
# V1        float64
# V2         object
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10        object
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class     float64
# dtype: object

# %%
for col in credited_card_df.columns:
    credited_card_df[col] = pd.to_numeric(credited_card_df[col], errors='coerce')
credited_card_df.fillna(0, inplace=True)

# %%
numeric_cols = credited_card_df.select_dtypes(include=[np.number]).columns.tolist()
mean_values = credited_card_df[numeric_cols].groupby(credited_card_df['Class']).mean()
print(mean_values)
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    32839.275862 -0.228727  0.030602   0.759633  0.161593 -0.225898
# 1.0    27808.103448 -7.617742  5.397133 -10.301469  5.744103 -5.594398
#
#              V6        V7        V8        V9  ...       V21       V22  \
# Class                                          ...
# 0.0    0.105444 -0.090376 -0.132953  0.184733  ... -0.084439 -0.136348
# 1.0   -2.275126 -7.866180  3.720923 -3.424236  ...  0.823134 -0.206046
#
#             V23       V24       V25       V26       V27       V28     Amount  \
# Class
# 0.0   -0.014727 -0.018533  0.113801  0.041817  0.061707  0.049380  94.515862
# 1.0   -0.260940 -0.079813  0.260578  0.116560  0.562943  0.025702  96.019931
#
#        Class
# Class
# 0.0      0.0
# 1.0      1.0
#
# [2 rows x 31 columns]

# %%
credited_card_df.fillna(0, inplace=True)  # or use credited_card_df.dropna(inplace=True)

# %%
credited_card_df.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    32839.275862 -0.228727  0.030602   0.759633  0.161593 -0.225898
# 1.0    27808.103448 -7.617742  5.397133 -10.301469  5.744103 -5.594398
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.105444 -0.090376 -0.132953  0.184733  ...  0.122495 -0.084439
# 1.0   -2.275126 -7.866180  3.720923 -3.424236  ...  0.428852  0.823134
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.136348 -0.014727 -0.018533  0.113801  0.041817  0.061707  0.049380
# 1.0   -0.206046 -0.260940 -0.079813  0.260578  0.116560  0.562943  0.025702
#
#           Amount
# Class
# 0.0    94.515862
# 1.0    96.019931
#
# [2 rows x 30 columns]

# %%
X = credited_card_df.drop('Class', axis=1)  # Features
Y = credited_card_df['Class']  # Target variable

# %%
X.shape
# Out:
# (290, 30)

# %%
Y.shape
# Out:
# (290,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = LogisticRegression(max_iter=300, solver='liblinear')  # Adjusted parameters

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=300, solver='liblinear')

# %%
ypred = model.predict(X_test)

# %%
accuracy = accuracy_score(Y_test, ypred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.86

# %%
accuracy_score(ypred,Y_test)
# Out:
# 0.8620689655172413
